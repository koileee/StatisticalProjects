# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import shapely
import pyshp
import geopandas
#df = pd.read_excel('File.xlsx', sheetname='Sheet1')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-2f8c267bfe45> in <module>
#       5 import seaborn as sns
#       6 import shapely
# ----> 7 import pyshp
#       8 import geopandas
#       9 #df = pd.read_excel('File.xlsx', sheetname='Sheet1')
#
# ModuleNotFoundError: No module named 'pyshp'

# %%
drought = pd.read_csv(r'Droughts.csv')
earnings=pd.read_csv(r'earnings.csv')
education=pd.read_csv(r'education.csv')

# %%
education.head()
# Out:
#    fips state          county  year  less_than_hs  hs_diploma  \
# 0     0    US   United States  1970      52373312    34158051
# 1  1000    AL         Alabama  1970       1062306      468269
# 2  1001    AL  Autauga County  1970          6611        3757
# 3  1003    AL  Baldwin County  1970         18726        8426
# 4  1005    AL  Barbour County  1970          8120        2242
#
#    some_college_or_associates  college_bachelors_or_higher  pct_less_than_hs  \
# 0                    11650730                     11717266              47.7
# 1                      136287                       141936              58.7
# 2                         933                          767              54.8
# 3                        2334                         2038              59.4
# 4                         581                          861              68.8
#
#    pct_hs_diploma  pct_college_or_associates  pct_college_bachelors_or_higher
# ...

# %%
import plotly.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot,iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
data = dict (type = 'choropleth', 
             locations = education['state'], 
             locationmode = 'USA-states', 
             colorscale = 'Greens',
             text = education['state'],
             z = education.groupby(['state'], as_index= False)['pct_college_bachelors_or_higher'].mean().pct_college_bachelors_or_higher,
             colorbar = {'title':'Color Bar Title goes here'}
            )

# %%
layout = dict(geo={'scope':'usa'})

# %%
choromap = go.Figure(data=[data], layout = layout)

# %%
iplot(choromap)
# Out:
# <div id="265502d2-88ad-45e9-b261-f92bbd5488d7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("265502d2-88ad-45e9-b261-f92bbd5488d7", [{"colorbar": {"title": "Color Bar Title goes here"}, "colorscale": "Greens", "locationmode": "USA-states", "locations": ["US", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL"], "text": ["US", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL"], "z": [5.822222222222223, 10.7], "type": "choropleth", "uid": "d0e620ec-c388-11e8-8840-3035ada90fca"}], {"geo": {"scope": "usa"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
education.groupby(['state'], as_index= False)['college_bachelors_or_higher'].sum().college_bachelors_or_higher
# Out:
# 0      151084
# 1    11717266
# Name: college_bachelors_or_higher, dtype: int64

# %%
earnings.describe()
# Out:
#               fips     total_med  total_agri_fish_mine  agri_fish_hunt  \
# count    10.000000     10.000000             10.000000         10.0000
# mean   1010.000000  27720.700000          29921.300000      29304.3000
# std       6.055301   3163.351881           9360.571778       9936.0694
# min    1001.000000  23504.000000          16167.000000      14464.0000
# 25%    1005.500000  24602.000000          22991.000000      23016.5000
# 50%    1010.000000  28432.500000          29351.000000      26476.0000
# 75%    1014.500000  30364.500000          36223.250000      36616.7500
# max    1019.000000  31811.000000          45237.000000      46064.0000
#
#        mining_quarrying_oilgas_extract  construction  manufacturing  \
# count                         7.000000     10.000000      10.000000
# mean                      36668.285714  27403.500000   32304.100000
# std                       23301.918674   3840.647493    7026.903087
# ...

# %%
industry = pd.read_csv('industry.csv')
# xl = pd.ExcelFile("dummydata.xlsx")
# xl.sheet_names
#[u'Sheet1', u'Sheet2', u'Sheet3']
# df = xl.parse("Sheet1")
# df.head()
#df = pandas.read_excel(open('your_xls_xlsx_filename','rb'), sheetname='Sheet 1')

# %%
industry['State'] = industry['county'].str.split(',').str[1]

# %%
industry.head()
# Out:
#            geo_id  fips                   county  total_employed  agriculture  \
# 0  0500000US01003  1003  Baldwin County, Alabama         77263.0       1302.0
# 1  0500000US01015  1015  Calhoun County, Alabama         42768.0        337.0
# 2  0500000US01043  1043  Cullman County, Alabama             NaN          NaN
# 3  0500000US01049  1049   DeKalb County, Alabama             NaN          NaN
# 4  0500000US01051  1051   Elmore County, Alabama             NaN          NaN
#
#    construction  manufacturing  wholesale_trade  retail_trade  \
# 0        6489.0         6134.0           2131.0        9525.0
# 1        1371.0         7868.0            750.0        5706.0
# 2           NaN            NaN              NaN           NaN
# 3           NaN            NaN              NaN           NaN
# 4           NaN            NaN              NaN           NaN
#
#    transport_utilities  information  finance_insurance_realestate  \
# ...

# %%
iplot(go.Figure(data=[data2], layout=layout2))
# Out:
# <div id="8985c722-ad73-4076-8fc7-78f50a8c3391" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8985c722-ad73-4076-8fc7-78f50a8c3391", [{"colorbar": {"title": "Color Bar Title goes here"}, "colorscale": "Greens", "locationmode": "USA-states", "locations": ["Alabama"], "text": ["hi"], "z": [50], "type": "choropleth", "uid": "4d4402e2-c38d-11e8-a09a-3035ada90fca"}], {"geo": {"scope": "usa"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
df_sample = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/laucnty16.csv')
df_sample['State FIPS Code'] = df_sample['State FIPS Code'].apply(lambda x: str(x).zfill(2))
df_sample['County FIPS Code'] = df_sample['County FIPS Code'].apply(lambda x: str(x).zfill(3))
df_sample['FIPS'] = df_sample['State FIPS Code'] + df_sample['County FIPS Code']

# %%
import plotly
import plotly.plotly as py
import plotly.figure_factory as ff


fips = industry[industry['total_employed'].notna()]['fips']
values = industry['total_employed']
fig = ff.create_choropleth(fips=fips, values=values, scope=['AL'])
py.iplot(fig)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~YuLicc41/12.embed" height="450px" width="900px"></iframe>

# %%
industry[industry['total_employed'].notna()]['fips']
# Out:
# 0    1003
# 1    1015
# 6    1069
# 7    1073
# 8    1077
# 9    1081
# Name: fips, dtype: int64

# %%
industry[industry['total_employed'].notna()]['total_employed']
# Out:
# 0     77263.0
# 1     42768.0
# 6     45470.0
# 7    289454.0
# 8     39581.0
# 9     63718.0
# Name: total_employed, dtype: float64

# %%
industry.head()
# Out:
#            geo_id  fips                   county  total_employed  agriculture  \
# 0  0500000US01003  1003  Baldwin County, Alabama         77263.0       1302.0
# 1  0500000US01015  1015  Calhoun County, Alabama         42768.0        337.0
# 2  0500000US01043  1043  Cullman County, Alabama             NaN          NaN
# 3  0500000US01049  1049   DeKalb County, Alabama             NaN          NaN
# 4  0500000US01051  1051   Elmore County, Alabama             NaN          NaN
#
#    construction  manufacturing  wholesale_trade  retail_trade  \
# 0        6489.0         6134.0           2131.0        9525.0
# 1        1371.0         7868.0            750.0        5706.0
# 2           NaN            NaN              NaN           NaN
# 3           NaN            NaN              NaN           NaN
# 4           NaN            NaN              NaN           NaN
#
#    transport_utilities  information  finance_insurance_realestate  \
# ...
