# %%
# original sound
from IPython.display import Audio
import scipy.io.wavfile
Fs, y = scipy.io.wavfile.read('train_bird.wav')
Audio(y, rate=Fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib.pyplot as plt
import numpy as np
N = len(y)
t = np.linspace(0, N/Fs, N)
plt.plot(t,y)
plt.xlabel("time (s)")
plt.ylabel("Amplitude")
plt.title("Original Signal")
plt.show()

# %%
from scipy.fftpack import fft, ifft
signals = fft(y)
index = np.arange(-N/2+1, N/2+1, 1)
plt.plot(index,np.abs(signals))
plt.xlabel("frequency")
plt.ylabel("Amplitude")
plt.title("Original Signal FFT")
# Out:
# Text(0.5, 1.0, 'Original Signal FFT')

# %% [markdown]
# Bird Sound

# %%
# Isolate bird sound, low pass filter on the train sound
p = int(2*N/7)
upperp = int(N*5/7)
newY = signals[p:upperp+1]
newY = np.append([0]*(p-1), newY)
newY= np.append(newY, [0]*(N-upperp))
birdsound = np.fft.ifft(newY)
Audio(sound, rate=Fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(t,birdsound)
plt.xlabel("time (s)")
plt.ylabel("Amplitude")
plt.title("isolate bird sound, low pass filter on train sound")
# Out:
# Text(0.5, 1.0, 'isolate bird sound, low pass filter on train sound')

# %%
plt.plot(index,newY)
plt.xlabel("frequency")
plt.ylabel("Amplitude")
plt.title("isolate bird sound, low pass filtered on train")
# Out:
# Text(0.5, 1.0, 'isolate bird sound, low pass filtered on train')

# %% [markdown]
# Train Sound

# %%
# Isolate Train Sound, high pass filter on the bird sound
p = int(2*N/7)
upperp = int(N*5/7)
newY_train = signals[:p]
newY_train = np.append(newY_train,[0]*(upperp-p))
newY_train= np.append(newY_train, signals[upperp:])
sound_train = np.fft.ifft(newY_train)
Audio(sound_train, rate=Fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(t,sound_train)
plt.xlabel("time (s)")
plt.ylabel("Amplitude")
plt.title("Isolate train sound, high pass filtered on bird")
# Out:
# Text(0.5, 1.0, 'Isolate train sound, high pass filtered on bird')

# %%
plt.plot(index,np.abs(newY_train))
plt.xlabel("frequency")
plt.ylabel("Amplitude")
plt.title("isolate train sound, high pass filtered on bird")
# Out:
# Text(0.5, 1.0, 'isolate train sound, high pass filtered on bird')
